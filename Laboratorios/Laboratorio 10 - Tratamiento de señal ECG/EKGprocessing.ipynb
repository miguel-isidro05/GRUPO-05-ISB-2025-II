# %% [markdown]
# # **Laboratorio 10: Procesamiento de señales ECG del database *LAB-EKG-PROCESSING***

# %%
import pickle

# %%
path_db = "F:\IB PUCP - UPCH\7mo Ciclo\Introducción a Señales Biomedicas\Grupo\LAB-EKG-PROCESSING\LAB-EKG-PROCESSING\ECG_DATASET\dataset_ekg.pkl"
with open(path_db, "rb") as f:
    dataset = pickle.load(f)

dataset
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\dell\AppData\Local\Temp\ipykernel_14976\4172802877.py:1: SyntaxWarning: invalid escape sequence '\I'
#   path_db = "F:\IB PUCP - UPCH\7mo Ciclo\Introducción a Señales Biomedicas\Grupo\LAB-EKG-PROCESSING\LAB-EKG-PROCESSING\ECG_DATASET\dataset_ekg.pkl"
# C:\Users\dell\AppData\Local\Temp\ipykernel_14976\4172802877.py:1: SyntaxWarning: invalid escape sequence '\I'
#   path_db = "F:\IB PUCP - UPCH\7mo Ciclo\Introducción a Señales Biomedicas\Grupo\LAB-EKG-PROCESSING\LAB-EKG-PROCESSING\ECG_DATASET\dataset_ekg.pkl"
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 2
#       1 path_db = "F:\IB PUCP - UPCH\7mo Ciclo\Introducción a Señales Biomedicas\Grupo\LAB-EKG-PROCESSING\LAB-EKG-PROCESSING\ECG_DATASET\dataset_ekg.pkl"
# ...
