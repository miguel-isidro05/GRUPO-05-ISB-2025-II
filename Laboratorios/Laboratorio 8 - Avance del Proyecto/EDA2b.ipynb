# %% [markdown]
# #1. Analisis exploratorio del dataset "BCI Competition IV 2b"

# %% [markdown]
# En este experimento participaron 9 sujetos, todos diestros, que realizaron tareas de imaginar el movimiento de la mano izquierda o derecha mientras se registraba su actividad cerebral.

# %% [markdown]
# > Cada sujeto tuvo 5 sesiones:
# >
# > - Las **dos primeras** fueron de **entrenamiento sin retroalimentación**, llamadas *screening sessions*.
# > - Las **tres últimas** incluyeron **feedback visual**,

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > En cada sesión se realizaron varios “runs” de 20 ensayos, donde el participante observaba una cruz de fijación, luego un estímulo visual (una flecha a la izquierda o a la derecha), y durante los siguientes 4 segundos debía imaginar el movimiento correspondiente de su mano igual que el 2a.
# >

# %% [markdown]
# Cada ensayo tuvo una duración promedio de **7.5 segundos**, con los siguientes eventos y tiempos:
#
# | Tiempo (s) | Evento | Descripción |
# |-------------|--------|--------------|
# | 0.0         | `T_inicio` | Inicio del ensayo, se muestra una cruz de fijación. |
# | 2.0         | `T_cue_onset` | Aparece una flecha (izquierda, derecha, arriba o abajo) que indica la clase de imaginación motora. |
# | 2.0–6.0     | `T_MI` | El participante realiza la imaginación motora correspondiente. |
# | 6.0–7.5     | `T_relax` | Periodo de descanso antes del siguiente ensayo. |
#
# Durante el periodo **2.0–6.0 s** se registran las señales EEG relevantes para el análisis, ya que es cuando se produce la activación cortical asociada al área motora.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Las señales se registraron desde tres derivaciones bipolares EEG:
# >
# >
# > **C3, Cz y C4**, localizadas sobre la corteza motora, con una frecuencia de muestreo de **250 Hz**, un rango de ±100 µV y filtros analógicos de 0.5 a 100 Hz.
# >
# > Además, se registraron **tres canales EOG** (electrooculograma) para poder eliminar los artefactos oculares.
# >

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > El propósito de este dataset es permitir el desarrollo y comparación de algoritmos de clasificación de señales EEG.
# >
# >
# > En particular, los sujetos realizan **dos clases de imaginación motora**:
# >
# > - Clase 1: **mano izquierda**
# > - Clase 2: **mano derecha**
#
# > En total, cada sujeto aporta 240 ensayos de entrenamiento (120 por clase), además de datos para evaluación.
# >

# %% [markdown]
# Resumen de la distribución de datos:

# %% [markdown]
# - **Sujetos:** 9
# - **Canales EEG:** 3 (C3, Cz, C4)
# - **Frecuencia de muestreo:** 250 Hz
# - **Clases:** 2 (mano izquierda, mano derecha)
# - **Duración de cada sesión:** 160 ensayos por sujeto

# %% [markdown]
# Comparación entre 2a y 2b:

# %% [markdown]
# - El **dataset 2a** incluye **22 canales EEG + 3 EOG**, lo cual permite una **mayor resolución espacial** sobre el córtex motor y ocular, con **4 clases de MI**.
# - El **dataset 2b** emplea únicamente los canales **C3, Cz y C4**, centrados en la **región motora primaria**, y contiene **2 clases de MI** (izquierda y derecha).
# - En ambos casos, las señales fueron grabadas con el mismo equipo y condiciones, pero el 2b se enfocó en minimizar artefactos para facilitar el estudio de **clasificadores de baja dimensionalidad**.

# %% [markdown]
# Link del dataset: https://bbci.de/competition/iv/download/
#
# Link del paper del dataset: https://www.bbci.de/competition/iv/desc_2b.pdf

# %% [markdown]
# ##1.1 Descargando archivos correspondientes

# %%
# !pip install mne gdown scipy numpy pandas seaborn matplotlib torch torchvision scikit-learn torchsummary
# Out:
# Collecting mne
#   Downloading mne-1.10.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.12/dist-packages (1.5.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.12/dist-packages (from mne) (0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mne) (25.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.12/dist-packages (from mne) (1.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from mne) (4.67.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.5->mne) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->mne) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading mne-1.10.2-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 63.5 MB/s eta 0:00:00
# Installing collected packages: mne
# Successfully installed mne-1.10.2

# %%
#Descarga directamente el dataset de BCI Competition IV 2b
# !wget https://www.bbci.de/competition/download/competition_iv/BCICIV_2b_gdf.zip
# Out:
# --2025-10-21 10:00:57--  https://www.bbci.de/competition/download/competition_iv/BCICIV_2b_gdf.zip
# Resolving www.bbci.de (www.bbci.de)... 141.23.71.83
# Connecting to www.bbci.de (www.bbci.de)|141.23.71.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 226710550 (216M) [application/zip]
# Saving to: ‘BCICIV_2b_gdf.zip’
#
# BCICIV_2b_gdf.zip   100%[===================>] 216.21M  25.8MB/s    in 9.1s
#
# 2025-10-21 10:01:06 (23.9 MB/s) - ‘BCICIV_2b_gdf.zip’ saved [226710550/226710550]

# %%
#Descomprime el archivo descargado en la MISMA CARPETA LOCAL (En mi caso /Proyect_EEG)
# !mkdir -p cleaned_data

# Descomprime los datos en crudo en raw_data
# !unzip BCICIV_2b_gdf.zip -d raw_data
# Out:
# Archive:  BCICIV_2b_gdf.zip
#   inflating: raw_data/B0101T.gdf
#   inflating: raw_data/B0102T.gdf
#   inflating: raw_data/B0103T.gdf
#   inflating: raw_data/B0104E.gdf
#   inflating: raw_data/B0105E.gdf
#   inflating: raw_data/B0201T.gdf
#   inflating: raw_data/B0202T.gdf
#   inflating: raw_data/B0203T.gdf
#   inflating: raw_data/B0204E.gdf
#   inflating: raw_data/B0205E.gdf
#   inflating: raw_data/B0301T.gdf
#   inflating: raw_data/B0302T.gdf
#   inflating: raw_data/B0303T.gdf
#   inflating: raw_data/B0304E.gdf
#   inflating: raw_data/B0305E.gdf
#   inflating: raw_data/B0401T.gdf
#   inflating: raw_data/B0402T.gdf
#   inflating: raw_data/B0403T.gdf
#   inflating: raw_data/B0404E.gdf
#   inflating: raw_data/B0405E.gdf
#   inflating: raw_data/B0501T.gdf
#   inflating: raw_data/B0502T.gdf
#   inflating: raw_data/B0503T.gdf
#   inflating: raw_data/B0504E.gdf
#   inflating: raw_data/B0505E.gdf
#   inflating: raw_data/B0601T.gdf
#   inflating: raw_data/B0602T.gdf
#   inflating: raw_data/B0603T.gdf
#   inflating: raw_data/B0604E.gdf
#   inflating: raw_data/B0605E.gdf
#   inflating: raw_data/B0701T.gdf
#   inflating: raw_data/B0702T.gdf
#   inflating: raw_data/B0703T.gdf
#   inflating: raw_data/B0704E.gdf
#   inflating: raw_data/B0705E.gdf
#   inflating: raw_data/B0801T.gdf
#   inflating: raw_data/B0802T.gdf
#   inflating: raw_data/B0803T.gdf
#   inflating: raw_data/B0804E.gdf
#   inflating: raw_data/B0805E.gdf
#   inflating: raw_data/B0901T.gdf
#   inflating: raw_data/B0902T.gdf
#   inflating: raw_data/B0903T.gdf
#   inflating: raw_data/B0904E.gdf
#   inflating: raw_data/B0905E.gdf

# %%
# Crear carpetas para datos limpios de las dos primeras sesiones
# !mkdir -p cleaned_data/first_session
# !mkdir -p cleaned_data/second_session
# !mkdir -p cleaned_data/fourth_session
# !mkdir -p cleaned_data/five_session

# %% [markdown]
# ## 1.2 Importar librerias y generando el dataset

# %%
#Importamos todas las librerias necesarias para procesar nuestro dataste y entrenar nuestro modelo de Deep Learning

import os #Para manejo de archivos y directorios
import mne #Para procesamiento de señales EEG
import math
import copy #Para hacer copias profundas de objetos
import gdown #Sirve para descargar archivos de Google Drive
import random
import scipy.io #Para trabajar con archivos .mat
import numpy as np #Para operaciones numéricas
import pandas as pd
import seaborn as sn #Para visualización de datos
import matplotlib.pyplot as plt #Para visualización de datos

# Torch
import torch
import torch.nn as nn #Para construir redes neuronales
import torch.optim as optim #Para optimizadores
import torch.nn.functional as F #Para funciones de activación y pérdida

from torchsummary import summary #Para resumir modelos de PyTorch
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset, random_split

# Scikit-Learn
from sklearn.feature_selection import mutual_info_classif #Para selección de características
from sklearn.metrics import confusion_matrix, accuracy_score #Para evaluar el rendimiento del modelo
from sklearn.model_selection import train_test_split #Para dividir los datos en conjuntos de entrenamiento y prueba

# %% [markdown]
# ## 2.1 Analisis Exploratorio de datos para un ejemplo especifico

# %% [markdown]
# La correcta comprensión del protocolo de adquisición fue esencial para:
# - Alinear los eventos y segmentos temporales exactos de interés (2–6 s).
# - Evitar la inclusión de artefactos pre o post evento.
# - Sincronizar correctamente las señales EEG con los **labels de clase**.
# - Garantizar la validez fisiológica de las características extraídas (bandas mu y beta).

# %% [markdown]
# Carga de los datos en formato .gdf del primer ejemplo para entender

# %%
#Ejemplo señal B0101T.gdf
raw_B010XT = mne.io.read_raw_gdf('raw_data/B0101T.gdf', eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
raw_B010XT.info
# Out:
# Extracting EDF parameters from /content/raw_data/B0101T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# /tmp/ipython-input-179274713.py:2: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw_B010XT = mne.io.read_raw_gdf('raw_data/B0101T.gdf', eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
#  chs: 6 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: 2005-10-25 09:35:11 UTC
#  nchan: 6
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: B01, sex: 0, last_name: X, birthday: 1984-12-01>
# >

# %% [markdown]
# Debemos entender cuales son los eventos que contienen a los eog y los otros con sus codigos respectivos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Convierte las anotaciones textuales en eventos numéricos
raw_B010XT.annotations
events = mne.events_from_annotations(raw_B010XT)
events[1]
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1077'), np.str_('1078'), np.str_('1079'), np.str_('1081'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('769'), np.str_('770')]
# {np.str_('1023'): 1,
#  np.str_('1077'): 2,
#  np.str_('1078'): 3,
#  np.str_('1079'): 4,
#  np.str_('1081'): 5,
#  np.str_('276'): 6,
#  np.str_('277'): 7,
#  np.str_('32766'): 8,
#  np.str_('768'): 9,
#  np.str_('769'): 10,
#  np.str_('770'): 11}

# %%
# Diccionario de eventos para BCI Competition IV - Dataset 2b
event_dict = {
    'rejected trial': 1,             # 1023
    'eye movement horizontal': 2,    # 1077
    'eye movement vertical': 3,      # 1078
    'eye rotation': 4,               # 1079
    'eye blink': 5,                  # 1081
    'idling open': 6,                # 276 (ojos abiertos)
    'idling closed': 7,              # 277 (ojos cerrados)
    'new run': 8,                    # 32766
    'start trial': 9,                # 768
    'left hand': 10,                 # 769 (clase 1)
    'right hand': 11                 # 770 (clase 2)
}

# Visualización de los eventos
fig = mne.viz.plot_events(
    events[0],
    event_id=event_dict,
    sfreq=raw_B010XT.info['sfreq'],
    first_samp=raw_B010XT.first_samp
)
fig.set_size_inches(15, 5)
# Out:
# /tmp/ipython-input-4064499525.py:17: RuntimeWarning: More events than default colors available. You should pass a list of unique colors.
#   fig = mne.viz.plot_events(

# %% [markdown]
# Generamos la epoch.

# %%
# Crear epochs para los eventos de interés (10, 11) desde 0.5 a 4 segundos (Buneas practicas no en 0)
epochs = mne.Epochs(raw_B010XT, events[0], event_id=[10,11], tmin=0.5, tmax=4, reject=None, baseline=None, preload=True)

# Extraer los datos y las etiquetas de las epochs
first_session_data= epochs.get_data(copy=True)

# Etiquetas de las primeras sesiones
first_session_labels = epochs.events[:,-1]
# Out:
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 120 events and 876 original time points ...
# 0 bad epochs dropped

# %% [markdown]
# Verificamos estuctura de las epochs.

# %%
#Obtenemos la info de cada epoch
epochs.get_data().shape
# Out:
# (120, 6, 876)

# %% [markdown]
# Como podemos observar, son 6 canales, de los cuales 3 son pertenecientes a los EEG y otros 3 pertenecientes a EOG.

# %%
#Leemos cuales son sus nombres
channel_names = epochs.ch_names
print(channel_names)
# Out:
# ['EEG:C3', 'EEG:Cz', 'EEG:C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']

# %% [markdown]
# Ahora si eliminamos los datos de las señales de oculograma pertencientes a ['EOG:ch01', 'EOG:ch02', 'EOG:ch03'], ya que no los utilizaremos para el procesamiento de las epochs.

# %%
#Si sale error recordar que solo se puede hacer esto una vez al realizar la accion
raw_B010XT.drop_channels(['EOG:ch01', 'EOG:ch02', 'EOG:ch03'])
# Out:
# <RawGDF | B0101T.gdf, 3 x 604803 (2419.2 s), ~13.9 MiB, data loaded>

# %% [markdown]
# Visualización de las señales brutas:

# %%
#Plot de la data
fig = raw_B010XT.plot(scalings='auto', show=False)
fig.set_size_inches(15, 10)
plt.show()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1500x1000 with 4 Axes>

# %%
raw_B010XT.plot_psd(tmin=0, tmax=60, fmin=2, fmax=80, average=True, spatial_colors=False);
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.192 (s)
# Plotting power spectral density (dB=True).
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# Filtramos al igual que el BCI Competition IV 2a para que obtengamos los valores en las bandas que nos interesan realmente.

# %%
raw_B010XT.filter(l_freq=8, h_freq=30, method='iir')
raw_B010XT.notch_filter(freqs=50)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
# <RawGDF | B0101T.gdf, 3 x 604803 (2419.2 s), ~13.9 MiB, data loaded>

# %%
#Plot de la data
fig = raw_B010XT.plot(scalings='auto', show=False)
fig.set_size_inches(15, 10)
plt.show()
# Out:
# <MNEBrowseFigure size 1500x1000 with 4 Axes>

# %%
raw_B010XT.plot_psd(tmin=0, tmax=60, fmin=2, fmax=80, average=True, spatial_colors=False);
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.192 (s)
# Plotting power spectral density (dB=True).
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# Ahora mostramos los trials que ocurrieron para el primer recording y obtenemos su PSD para identificar el decremento de la amplitud en las bandas beta y mu (sobretodo beta), acorde a las ERDs.

# %%
# Mostrar el primer trial (epoch 0) con los 6 canales
fig = epochs[0].plot(n_channels=3,scalings='auto',title='Trial 0 - 3 canales', show=False)
fig.set_size_inches(15, 10)

# Obtener frecuencia de muestreo
sfreq = epochs.info['sfreq']
# Out:
# <MNEBrowseFigure size 1500x1000 with 4 Axes>

# %%
# Calcular la PSD con el método Welch (puedes usar multitaper también)
epo_spectrum = epochs.compute_psd(method='welch', fmin=4, fmax=40, n_fft=256)

# Obtener datos PSD y sus frecuencias
psds, freqs = epo_spectrum.get_data(return_freqs=True)
print(f"PSDs shape: {psds.shape}, freqs shape: {freqs.shape}")

# Graficar el PSD promedio sobre todos los epochs (por canal)
# average=True: promedio de los 288 trials (no cada trial individual).
fig=epo_spectrum.plot(average=True, dB=True, spatial_colors=True)
fig.set_size_inches(15, 10)
plt.show()
# Out:
# Effective window size : 1.024 (s)
# PSDs shape: (120, 6, 36), freqs shape: (36,)
# Plotting power spectral density (dB=True).
# Averaging across epochs before plotting...
# <MNELineFigure size 1500x1000 with 1 Axes>

# %% [markdown]
# Es normal que exista gran variabilidad en los datos, ya que recordemos que solo tenemos 3 canales no como en el BCI competition IV 2a que tenemos 22.

# %% [markdown]
# # 3. Preprocesamiento y procesamiento de datos a las sesiones generales

# %% [markdown]
# ## 3.1 Primera sesión

# %% [markdown]
# En el dataset BCI Competition IV 2a, los archivos están nombrados según el tipo de sesión:
#
# | Sufijo | Significado               | Ejemplo       | Contenido / Uso                                                                 |
# |--------|---------------------------|---------------|---------------------------------------------------------------------------------|
# | T      | Training (Entrenamiento)  | B0101T.gdf, B0102T.gdf | Contienen todas las etiquetas de clase y se usan para entrenar el modelo.        |
# | E      | Evaluation / Test (Prueba)| B0104E.gdf, B0105E.gdf | No contienen todas las etiquetas de clase; se usan para evaluar el desempeño del modelo. |

# %%
#NOTA: MNE tiene su propio sistema de logging (mensajes de información), por defecto.

# Definir las rutas de las carpetas
raw_data_folder = "raw_data/"
cleaned_data_folder = "cleaned_data/first_session/"
files = os.listdir(raw_data_folder) # devuelve una lista con los nombres de los archivos enlistados: ['A01T.gdf', 'A01E.gdf', 'A02T.gdf', ...]

# Aquí se está filtrando la lista de archivos para quedarse solo con los que terminan en .T.gdf (archivos de entrenamiento)
filtered_files = [file for file in files if file.endswith('01T.gdf')]

# Inicializar una lista para almacenar los datos
raw_list = []

# Iterar sobre los archivos filtrados y cargar los datos
for file in filtered_files:
    file_path = os.path.join(raw_data_folder, file) # Construir la ruta completa del archivo (.../.../...)

    # Cargar el archivo GDF usando MNE y especificar los canales EOG
    raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)

    # Eliminar los canales EOG del raw data para cada
    raw.drop_channels(['EOG:ch01', 'EOG:ch02', 'EOG:ch03'])

    # High Pass Filtering 8-30 Hz
    raw.filter(l_freq=8, h_freq=30, method='iir')

    # Notch filter for Removal of Line Voltage
    raw.notch_filter(freqs=50)

    # Guardar el archivo limpio en formato .fif en la carpeta cleaned_data/first_session
    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')
    raw.save(new_file_path, overwrite=True)

    # Añadir el objeto raw a la lista
    raw_list.append(raw)

# Concatenar si hay archivos cargados
if raw_list:
    final_raw = mne.concatenate_raws(raw_list)

    # Guardar archivo concatenado en .fif
    new_file_path = os.path.join(cleaned_data_folder, 'First_Session_Subjects.fif')
    final_raw.save(new_file_path, overwrite=True)
else:
    print("No se encontraron archivos .T.gdf en la carpeta raw_data.")
# Out:
# Extracting EDF parameters from /content/raw_data/B0401T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# /tmp/ipython-input-4291800830.py:19: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/B0401T.fif
# /tmp/ipython-input-4291800830.py:32: RuntimeWarning: This filename (/content/cleaned_data/first_session/B0401T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/B0401T.fif
# [done]
# Extracting EDF parameters from /content/raw_data/B0801T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 787728  =      0.000 ...  3150.912 secs...
# /tmp/ipython-input-4291800830.py:19: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/B0801T.fif
# /tmp/ipython-input-4291800830.py:32: RuntimeWarning: This filename (/content/cleaned_data/first_session/B0801T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/B0801T.fif
# [done]
# Extracting EDF parameters from /content/raw_data/B0601T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# /tmp/ipython-input-4291800830.py:19: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/B0601T.fif
# /tmp/ipython-input-4291800830.py:32: RuntimeWarning: This filename (/content/cleaned_data/first_session/B0601T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/B0601T.fif
# [done]
# Extracting EDF parameters from /content/raw_data/B0701T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# /tmp/ipython-input-4291800830.py:19: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/B0701T.fif
# /tmp/ipython-input-4291800830.py:32: RuntimeWarning: This filename (/content/cleaned_data/first_session/B0701T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/B0701T.fif
# [done]
# Extracting EDF parameters from /content/raw_data/B0901T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# /tmp/ipython-input-4291800830.py:19: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/B0901T.fif
# /tmp/ipython-input-4291800830.py:32: RuntimeWarning: This filename (/content/cleaned_data/first_session/B0901T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/B0901T.fif
# [done]
# Extracting EDF parameters from /content/raw_data/B0201T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# /tmp/ipython-input-4291800830.py:19: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/B0201T.fif
# /tmp/ipython-input-4291800830.py:32: RuntimeWarning: This filename (/content/cleaned_data/first_session/B0201T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/B0201T.fif
# [done]
# Extracting EDF parameters from /content/raw_data/B0101T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# /tmp/ipython-input-4291800830.py:19: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/B0101T.fif
# /tmp/ipython-input-4291800830.py:32: RuntimeWarning: This filename (/content/cleaned_data/first_session/B0101T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/B0101T.fif
# [done]
# Extracting EDF parameters from /content/raw_data/B0501T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# /tmp/ipython-input-4291800830.py:19: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/B0501T.fif
# Closing /content/cleaned_data/first_session/B0501T.fif
# [done]
# Extracting EDF parameters from /content/raw_data/B0301T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# /tmp/ipython-input-4291800830.py:32: RuntimeWarning: This filename (/content/cleaned_data/first_session/B0501T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# /tmp/ipython-input-4291800830.py:19: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/B0301T.fif
# Closing /content/cleaned_data/first_session/B0301T.fif
# [done]
# /tmp/ipython-input-4291800830.py:32: RuntimeWarning: This filename (/content/cleaned_data/first_session/B0301T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Writing /content/cleaned_data/first_session/First_Session_Subjects.fif
# /tmp/ipython-input-4291800830.py:43: RuntimeWarning: This filename (/content/cleaned_data/first_session/First_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/First_Session_Subjects.fif
# [done]

# %%
#Anotacion de los eventos que ocurren
events = mne.events_from_annotations(final_raw)

# Crear epochs para los eventos de interés (10,11) desde 0 a 4 segundos
epochs = mne.Epochs(final_raw, events[0], event_id=[10,11], tmin=0.5, tmax=4, reject=None, baseline=None, preload=True)

# Extraer los datos y las etiquetas de las epochs
first_session_data = epochs.get_data(copy=True)

# Etiquetas de las primeras sesiones
first_session_labels = epochs.events[:,-1]

print("First Session Dataset shape:", first_session_data.shape)
print("Total etiquetas cargadas:", first_session_labels.shape)
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1077'), np.str_('1078'), np.str_('1079'), np.str_('1081'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('769'), np.str_('770')]
# Not setting metadata
# 1120 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1120 events and 876 original time points ...
# 0 bad epochs dropped
# First Session Dataset shape: (1120, 3, 876)
# Total etiquetas cargadas: (1120,)

# %% [markdown]
# ## 3.2 Cuarta session

# %% [markdown]
# Link: https://www.bbci.de/competition/iv/results/ds2b/true_labels.zip
#
# Descargamos y descomprimimos para obtener los labels de la sesión que sirve para evaluar.

# %%
# !wget https://www.bbci.de/competition/iv/results/ds2b/true_labels.zip
# !unzip true_labels.zip -d fourth_session_labels
# Out:
# --2025-10-21 10:57:39--  https://www.bbci.de/competition/iv/results/ds2b/true_labels.zip
# Resolving www.bbci.de (www.bbci.de)... 141.23.71.83
# Connecting to www.bbci.de (www.bbci.de)|141.23.71.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14660 (14K) [application/zip]
# Saving to: ‘true_labels.zip’
#
# true_labels.zip     100%[===================>]  14.32K  --.-KB/s    in 0s
#
# 2025-10-21 10:57:39 (202 MB/s) - ‘true_labels.zip’ saved [14660/14660]
#
# Archive:  true_labels.zip
#   inflating: fourth_session_labels/B0401T.mat
#   inflating: fourth_session_labels/B0403T.mat
#   inflating: fourth_session_labels/B0601T.mat
#   inflating: fourth_session_labels/B0202T.mat
#   inflating: fourth_session_labels/B0603T.mat
#   inflating: fourth_session_labels/B0104E.mat
#   inflating: fourth_session_labels/B0105E.mat
#   inflating: fourth_session_labels/B0802T.mat
#   inflating: fourth_session_labels/B0305E.mat
#   inflating: fourth_session_labels/B0501T.mat
#   inflating: fourth_session_labels/B0405E.mat
#   inflating: fourth_session_labels/B0702T.mat
#   inflating: fourth_session_labels/B0705E.mat
#   inflating: fourth_session_labels/B0605E.mat
#   inflating: fourth_session_labels/B0904E.mat
#   inflating: fourth_session_labels/B0203T.mat
#   inflating: fourth_session_labels/B0103T.mat
#   inflating: fourth_session_labels/B0404E.mat
#   inflating: fourth_session_labels/B0701T.mat
#   inflating: fourth_session_labels/B0505E.mat
#   inflating: fourth_session_labels/B0201T.mat
#   inflating: fourth_session_labels/B0301T.mat
#   inflating: fourth_session_labels/B0901T.mat
#   inflating: fourth_session_labels/B0205E.mat
#   inflating: fourth_session_labels/B0602T.mat
#   inflating: fourth_session_labels/B0801T.mat
#   inflating: fourth_session_labels/B0803T.mat
#   inflating: fourth_session_labels/B0902T.mat
#   inflating: fourth_session_labels/B0502T.mat
#   inflating: fourth_session_labels/B0703T.mat
#   inflating: fourth_session_labels/B0204E.mat
#   inflating: fourth_session_labels/B0402T.mat
#   inflating: fourth_session_labels/B0905E.mat
#   inflating: fourth_session_labels/B0704E.mat
#   inflating: fourth_session_labels/B0102T.mat
#   inflating: fourth_session_labels/B0604E.mat
#   inflating: fourth_session_labels/B0303T.mat
#   inflating: fourth_session_labels/B0804E.mat
#   inflating: fourth_session_labels/B0903T.mat
#   inflating: fourth_session_labels/B0503T.mat
#   inflating: fourth_session_labels/B0805E.mat
#   inflating: fourth_session_labels/B0304E.mat
#   inflating: fourth_session_labels/B0504E.mat
#   inflating: fourth_session_labels/B0101T.mat
#   inflating: fourth_session_labels/B0302T.mat

# %%
mat_data = scipy.io.loadmat("/content/fourth_session_labels/B0104E.mat")  # ejemplo
print(mat_data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'classlabel'])

# %%
raw_data_folder = 'raw_data/'
cleaned_data_folder = 'cleaned_data/fourth_session/'
mat_folder = 'fourth_session_labels/'

# Filtrar archivos .mat para las etiquetas (ejemplo 4E.mat)
mat_files = os.listdir(mat_folder)
filtered_math_labels = [file for file in mat_files if file.endswith('04E.mat')]

# Filtrar archivos .gdf para la sesión (ejemplo 4E.gdf)
files = os.listdir(raw_data_folder)
filtered_files = [file for file in files if file.endswith('04E.gdf')]

raw_list = []
fourth_session_labels = np.array([])

# Iteración sobre los .gdf
for file in filtered_files:
    file_path = os.path.join(raw_data_folder, file)

    # Leer datos
    raw = mne.io.read_raw_gdf(file_path,
                              eog=['EOG-left', 'EOG-central', 'EOG-right'],
                              preload=True)
    raw.drop_channels(['EOG:ch01', 'EOG:ch02', 'EOG:ch03'])
    raw.filter(l_freq=8, h_freq=30, method='iir')

    # Guardar .fif
    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')
    raw.save(new_file_path, overwrite=True)

    raw_list.append(raw)

    # Cargar labels del .mat correspondiente
    mat_file_name = file.replace('.gdf', '.mat')
    mat_file_path = os.path.join(mat_folder, mat_file_name)
    print(f"data:{file}, label:{mat_file_name}")

    if os.path.exists(mat_file_path):
        mat_data = scipy.io.loadmat(mat_file_path)
        class_labels = mat_data.get('classlabel', [])

        if class_labels.size > 0:
            class_labels_array = np.array(class_labels, dtype=int).flatten()
            fourth_session_labels = np.concatenate(
                (fourth_session_labels, class_labels_array)
            )
            print(f"Etiquetas cargadas: {class_labels_array.shape[0]}")
        else:
            print(f"Warning: 'classlabel' not found or empty in {mat_file_name}.")
    else:
        print(f"Warning: {mat_file_name} not found.")

# Concatenamos todos los raws
final_raw = mne.concatenate_raws(raw_list)
new_file_path = os.path.join(cleaned_data_folder, 'Fourth_Session_Subjects.fif')
final_raw.save(new_file_path, overwrite=True)
# Out:
# Extracting EDF parameters from /content/raw_data/B0904E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 466802  =      0.000 ...  1867.208 secs...
# /tmp/ipython-input-3638845600.py:21: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/fourth_session/B0904E.fif
# Closing /content/cleaned_data/fourth_session/B0904E.fif
# [done]
# data:B0904E.gdf, label:B0904E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0604E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 469990  =      0.000 ...  1879.960 secs...
# /tmp/ipython-input-3638845600.py:29: RuntimeWarning: This filename (/content/cleaned_data/fourth_session/B0904E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# /tmp/ipython-input-3638845600.py:21: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/fourth_session/B0604E.fif
# Closing /content/cleaned_data/fourth_session/B0604E.fif
# [done]
# data:B0604E.gdf, label:B0604E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0404E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 467478  =      0.000 ...  1869.912 secs...
# /tmp/ipython-input-3638845600.py:29: RuntimeWarning: This filename (/content/cleaned_data/fourth_session/B0604E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# /tmp/ipython-input-3638845600.py:21: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/fourth_session/B0404E.fif
# /tmp/ipython-input-3638845600.py:29: RuntimeWarning: This filename (/content/cleaned_data/fourth_session/B0404E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/fourth_session/B0404E.fif
# [done]
# data:B0404E.gdf, label:B0404E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0204E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 361829  =      0.000 ...  1447.316 secs...
# /tmp/ipython-input-3638845600.py:21: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/fourth_session/B0204E.fif
# Closing /content/cleaned_data/fourth_session/B0204E.fif
# [done]
# data:B0204E.gdf, label:B0204E.mat
# Etiquetas cargadas: 120
# Extracting EDF parameters from /content/raw_data/B0104E.gdf...
# GDF file detected
# /tmp/ipython-input-3638845600.py:29: RuntimeWarning: This filename (/content/cleaned_data/fourth_session/B0204E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 466313  =      0.000 ...  1865.252 secs...
# /tmp/ipython-input-3638845600.py:21: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/fourth_session/B0104E.fif
# /tmp/ipython-input-3638845600.py:29: RuntimeWarning: This filename (/content/cleaned_data/fourth_session/B0104E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/fourth_session/B0104E.fif
# [done]
# data:B0104E.gdf, label:B0104E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0804E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 474834  =      0.000 ...  1899.336 secs...
# /tmp/ipython-input-3638845600.py:21: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/fourth_session/B0804E.fif
# /tmp/ipython-input-3638845600.py:29: RuntimeWarning: This filename (/content/cleaned_data/fourth_session/B0804E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/fourth_session/B0804E.fif
# [done]
# data:B0804E.gdf, label:B0804E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0304E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 464674  =      0.000 ...  1858.696 secs...
# /tmp/ipython-input-3638845600.py:21: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/fourth_session/B0304E.fif
# /tmp/ipython-input-3638845600.py:29: RuntimeWarning: This filename (/content/cleaned_data/fourth_session/B0304E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/fourth_session/B0304E.fif
# [done]
# data:B0304E.gdf, label:B0304E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0504E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 417019  =      0.000 ...  1668.076 secs...
# /tmp/ipython-input-3638845600.py:21: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/fourth_session/B0504E.fif
# /tmp/ipython-input-3638845600.py:29: RuntimeWarning: This filename (/content/cleaned_data/fourth_session/B0504E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/fourth_session/B0504E.fif
# [done]
# data:B0504E.gdf, label:B0504E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0704E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 470343  =      0.000 ...  1881.372 secs...
# /tmp/ipython-input-3638845600.py:21: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/fourth_session/B0704E.fif
# /tmp/ipython-input-3638845600.py:29: RuntimeWarning: This filename (/content/cleaned_data/fourth_session/B0704E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/fourth_session/B0704E.fif
# [done]
# data:B0704E.gdf, label:B0704E.mat
# Etiquetas cargadas: 160
# Writing /content/cleaned_data/fourth_session/Fourth_Session_Subjects.fif
# /tmp/ipython-input-3638845600.py:56: RuntimeWarning: This filename (/content/cleaned_data/fourth_session/Fourth_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/fourth_session/Fourth_Session_Subjects.fif
# [done]
# [PosixPath('/content/cleaned_data/fourth_session/Fourth_Session_Subjects.fif')]

# %%
from scipy.io import loadmat

# Cargar el archivo .mat que tiene las etiquetas
mat_data = loadmat("fourth_session_labels/B0104E.mat")   # ajusta con tu archivo real
labels_mat = mat_data['classlabel'].squeeze()  # (160,)
print(labels_mat.shape)  # debería dar (160,)

print("Total etiquetas:", labels_mat.shape[0])
print("Ejemplo de clases únicas:", np.unique(labels_mat))
# Out:
# (160,)
# Total etiquetas: 160
# Ejemplo de clases únicas: [1 2]

# %%
events, event_dict = mne.events_from_annotations(final_raw)
events[1]

# Mostrar los eventos únicos encontrados
print("Eventos encontrados:", event_dict)

print(events.shape)
print(events[:5])  # Primeros 5 eventos

epochs = mne.Epochs(final_raw, events, event_id=11, tmin=0.5, tmax=4, reject=None, baseline=None, preload=None)

fourth_session_data = epochs.get_data(copy=True)

print("\nFourth Session Dataset shape:", fourth_session_data.shape)
print("Total etiquetas cargadas:", fourth_session_labels.shape)
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1077'), np.str_('1078'), np.str_('1079'), np.str_('1081'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('781'), np.str_('783')]
# Eventos encontrados: {np.str_('1023'): 1, np.str_('1077'): 2, np.str_('1078'): 3, np.str_('1079'): 4, np.str_('1081'): 5, np.str_('276'): 6, np.str_('277'): 7, np.str_('32766'): 8, np.str_('768'): 9, np.str_('781'): 10, np.str_('783'): 11}
# (4566, 3)
# [[    0     0     8]
#  [  499     0     6]
#  [16749     0     7]
#  [32999     0     5]
#  [37999     0     4]]
# Not setting metadata
# 1400 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1400 events and 876 original time points ...
# 0 bad epochs dropped
#
# Fourth Session Dataset shape: (1400, 3, 876)
# Total etiquetas cargadas: (1400,)

# %% [markdown]
# # 4. Entrenamiento y evaluación del modelo

# %% [markdown]
# ## 4.1 Estructura y preparación de datos

# %%
# Choosing Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Loss Function
criterion = nn.CrossEntropyLoss()

# Normalizing Labels to [0, 1, 2, 3]
y_train = first_session_labels - np.min(first_session_labels)
y_test = fourth_session_labels - np.min(fourth_session_labels)

# Normalizing Input features: z-score(mean=0, std=1)
X_first_session = (first_session_data - np.mean(first_session_data)) / np.std(first_session_data)
X_fourth_session = (fourth_session_data - np.mean(fourth_session_data)) / np.std(fourth_session_data)

X = np.concatenate((X_first_session, X_fourth_session))
y = np.concatenate((y_train, y_test))

# Spliting  Data: 90% for Train and 10% for Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, stratify=y)

# Converting to Tensor
X_train = torch.Tensor(X_train).unsqueeze(1).to(device)
X_test = torch.Tensor(X_test).unsqueeze(1).to(device)
y_train = torch.LongTensor(y_train).to(device)
y_test = torch.LongTensor(y_test).to(device)

# Creating Tensor Dataset
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

# Printing the sizes
print("Size of X_train:", X_train.size())
print("Size of X_test:", X_test.size())
print("Size of y_train:", y_train.size())
print("Size of y_test:", y_test.size())
# Out:
# Size of X_train: torch.Size([2268, 1, 3, 876])
# Size of X_test: torch.Size([252, 1, 3, 876])
# Size of y_train: torch.Size([2268])
# Size of y_test: torch.Size([252])

# %% [markdown]
# ## 4.2 Clase de entrenamiento

# %%
#TrainModel es una clase que encapsula el proceso de
#entrenamiento de un modelo de red neuronal utilizando PyTorch.

class TrainModel():
    def __init__(self,):
        # Establece el dispositivo para PyTorch (GPU si está disponible, de lo contrario CPU)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Método para entrenar el modelo

    # Batch size: número de muestras que se procesan antes de actualizar el modelo
    # Epochs: número de veces que el modelo verá todo el conjunto de datos de entrenamiento

    def train_model(self, model, train_dataset, learning_rate=0.001, batch_size=64, epochs=500):
        model = model.to(self.device) # Mover el modelo al dispositivo adecuado (CPU o GPU)
        criterion = nn.CrossEntropyLoss()

        # Definir el optimizador Adam
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

        # Variables para seguimiento del rendimiento
        highest_train_accuracy = 0.0

        # Bucle de entrenamiento
        for epoch in range(epochs):
            model.train() # train mode - activa dropout y batchnorm si están presentes
            running_loss = 0.0
            correct = 0
            total = 0

            # Iterar sobre los lotes de datos
            for inputs, labels in train_loader:

                # Mover los datos al dispositivo adecuado (CPU o GPU)
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                # Procesos de forward y backward pass
                # y actualización de pesos del modelo
                optimizer.zero_grad() # Limpiar los gradientes acumulados

                #Forward pass: pasamos los datos por el modelo
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                #Backward pass: aplicamos backpropagation
                loss.backward()
                optimizer.step()

                # Estadísticas de pérdida y precisión
                running_loss += loss.item() * inputs.size(0) # Suma la pérdida del lote actual
                _, predicted = torch.max(outputs, 1) # Obtiene las predicciones del modelo

                # Cuenta el número total de etiquetas y las predicciones correctas
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

            epoch_loss = running_loss / len(train_loader.dataset)
            epoch_accuracy = correct / total

            # Actualiza la mejor precisión de entrenamiento si es necesario
            if epoch_accuracy > highest_train_accuracy:
                highest_train_accuracy = epoch_accuracy

            print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {(epoch_accuracy*100):.2f}%")

        # Estadísticas finales después del entrenamiento
        average_loss = running_loss / len(train_loader.dataset)
        print("Average Loss:", average_loss)
        print("Highest Train Accuracy:", highest_train_accuracy)

        # Saving model
        torch.save(model.state_dict(), 'eegnet_model.pth')
        return model

# %% [markdown]
# ## 4.3 Clase de evaluación de modelo

# %%
# EvalModel es una clase que encapsula el proceso de evaluación de un modelo de red neuronal utilizando PyTorch.
class EvalModel():
    def __init__(self, model):
        self.model = model.to(device)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Método para probar el modelo en un conjunto de datos de prueba y calcular la precisión de clasificación
    def test_model(self, test_dataset):

        # Poner el modelo en modo de evaluación
        self.model.eval() # Desactiva dropout y batch normalization si están presentes
        correct = 0
        total = 0

        # Crear un DataLoader para el conjunto de datos de prueba
        test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

        # Desactivar el cálculo de gradientes para la evaluación
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        # Calcular y mostrar la precisión
        accuracy = (correct / total) * 100
        print("/------------------------------/")
        print(f"Test Accuracy: {accuracy:.2f}%")
        print("/------------------------------/")
        return accuracy

    #
    def plot_confusion_matrix(self, test_dataset, classes):
        self.model.eval()
        y_pred = []
        y_true = []
        test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

        with torch.no_grad():
            #from: https://github.com/github-copilot/code_referencing?cursor=39e277800e17a96819fae3ffbe2dca5e&editor=vscode
            for entradas, etiquetas in test_loader:
                entradas = entradas.to(self.device)
                etiquetas = etiquetas.to(self.device)

                salidas = self.model(entradas)
                _, predicho = torch.max(salidas.data, 1)

                y_pred.append(predicho.item())
                y_true.append(etiquetas.item())

        # Calcular la matriz de confusión
        cf_matrix = confusion_matrix(y_true, y_pred)
        cf_matrix = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]

        df_cm = pd.DataFrame(cf_matrix, index=classes, columns=classes)

        # Visualizar la matriz de confusión usando seaborn
        plt.figure(figsize=(10, 7))
        sn.heatmap(df_cm, annot=True, cmap='Blues', fmt='.2f')
        plt.xlabel('Predicted labels')
        plt.ylabel('True labels')
        plt.title('Confusion Matrix')
        plt.savefig('confusion_matrix_model.png')
        plt.show()

# %% [markdown]
# ## 4.4 Arquitectura de EEGnet

# %%
# Definición del modelo EEGNet en PyTorch
class EEGNetModel(nn.Module): # EEGNET-8,2
    def __init__(self, chans=3, classes=2, time_points=876, temp_kernel=32,
                 f1=16, f2=32, d=2, pk1=8, pk2=16, dropout_rate=0.5, max_norm1=1, max_norm2=0.25):

        super(EEGNetModel, self).__init__()
        # Calculating FC input features
        linear_size = (time_points//(pk1*pk2))*f2

        # Temporal Filters
        self.block1 = nn.Sequential(
            nn.Conv2d(1, f1, (1, temp_kernel), padding='same', bias=False),
            nn.BatchNorm2d(f1),
        )
        # Spatial Filters
        self.block2 = nn.Sequential(
            nn.Conv2d(f1, d * f1, (chans, 1), groups=f1, bias=False), # Depthwise Conv
            nn.BatchNorm2d(d * f1),
            nn.ELU(),
            nn.AvgPool2d((1, pk1)),
            nn.Dropout(dropout_rate)
        )

        # Separable Conv
        self.block3 = nn.Sequential(
            nn.Conv2d(d * f1, f2, (1, 16),  groups=f2, bias=False, padding='same'), # Separable Conv
            nn.Conv2d(f2, f2, kernel_size=1, bias=False), # Pointwise Conv
            nn.BatchNorm2d(f2),
            nn.ELU(),
            nn.AvgPool2d((1, pk2)),
            nn.Dropout(dropout_rate)
        )
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(linear_size, classes)

        # Apply max_norm constraint to the depthwise layer in block2
        self._apply_max_norm(self.block2[0], max_norm1)

        # Apply max_norm constraint to the linear layer
        self._apply_max_norm(self.fc, max_norm2)

    # Función para aplicar la restricción de norma máxima a los pesos de una capa
    # Esto ayuda a prevenir el sobreajuste y mejora la generalización del modelo
    # En resumen: aplica restricciones a los pesos para que no crezcan demasiado.

    def _apply_max_norm(self, layer, max_norm):
        for name, param in layer.named_parameters():
            if 'weight' in name:
                param.data = torch.renorm(param.data, p=2, dim=0, maxnorm=max_norm)

    # Definición del paso hacia adelante (forward pass) del modelo.
    # Aquí es donde se define cómo los datos fluyen a través de las diferentes capas del modelo.
    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.flatten(x)
        x = self.fc(x) #Salida de 2 en vez de 4

        return x

# %% [markdown]
# ## 4.6 Entrenamiento y resumen

# %%
#Estructura del modelo EEGNet
input_size = (1, 3, 876)

# Crear una instancia del modelo EEGNet y moverlo al dispositivo adecuado (CPU o GPU)
eegnet_model = EEGNetModel(classes=2).to(device)

summary(eegnet_model, input_size)

# Training Hyperparameters
EPOCHS = 500
BATCH_SIZE = 64
LEARNING_RATE = 0.001
trainer = TrainModel() # Instancia de la clase TrainModel

# Entrenar el modelo EEGNet y guardar los pesos entrenados
trained_eegnet_model = trainer.train_model(eegnet_model, train_dataset, learning_rate=LEARNING_RATE,batch_size=BATCH_SIZE, epochs=EPOCHS)

# Evaluar el modelo entrenado usando el conjunto de datos de prueba
torch.save(trained_eegnet_model.state_dict(), 'eegnet2b_model.pth')
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:543: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1027.)
#   return F.conv2d(
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 3, 876]             512
#        BatchNorm2d-2           [-1, 16, 3, 876]              32
#             Conv2d-3           [-1, 32, 1, 876]              96
#        BatchNorm2d-4           [-1, 32, 1, 876]              64
#                ELU-5           [-1, 32, 1, 876]               0
#          AvgPool2d-6           [-1, 32, 1, 109]               0
#            Dropout-7           [-1, 32, 1, 109]               0
#             Conv2d-8           [-1, 32, 1, 109]             512
#             Conv2d-9           [-1, 32, 1, 109]           1,024
#       BatchNorm2d-10           [-1, 32, 1, 109]              64
#               ELU-11           [-1, 32, 1, 109]               0
#         AvgPool2d-12             [-1, 32, 1, 6]               0
#           Dropout-13             [-1, 32, 1, 6]               0
#           Flatten-14                  [-1, 192]               0
#            Linear-15                    [-1, 2]             386
# ================================================================
# Total params: 2,690
# Trainable params: 2,690
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.45
# Params size (MB): 0.01
# Estimated Total Size (MB): 1.47
# ----------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-822804777.py in <cell line: 0>()
#      14
#      15 # Entrenar el modelo EEGNet y guardar los pesos entrenados
# ---> 16 trained_eegnet_model = trainer.train_model(eegnet_model, train_dataset, learning_rate=LEARNING_RATE,batch_size=BATCH_SIZE, epochs=EPOCHS)
#      17
#      18 # Evaluar el modelo entrenado usando el conjunto de datos de prueba
#
# /tmp/ipython-input-381474688.py in train_model(self, model, train_dataset, learning_rate, batch_size, epochs)
#      17
#      18         # Definir el optimizador Adam
# ---> 19         optimizer = optim.Adam(model.parameters(), lr=learning_rate)
#      20         train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#      21
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in __init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused, decoupled_weight_decay)
#      99             decoupled_weight_decay=decoupled_weight_decay,
#     100         )
# --> 101         super().__init__(params, defaults)
#     102
#     103         if fused:
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in __init__(self, params, defaults)
#     398
#     399         for param_group in param_groups:
# --> 400             self.add_param_group(cast(dict, param_group))
#     401
#     402         # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#
# /usr/local/lib/python3.12/dist-packages/torch/_compile.py in inner(*args, **kwargs)
#      44             disable_fn = getattr(fn, "__dynamo_disable", None)
#      45             if disable_fn is None:
# ---> 46                 import torch._dynamo
#      47
#      48                 # We can safely turn off functools.wraps here because the inner
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/__init__.py in <module>
#      11 import torch
#      12
# ---> 13 from . import config, convert_frame, eval_frame, resume_execution
#      14 from .backends.registry import list_backends, lookup_backend, register_backend
#      15 from .callback import callback_handler, on_compile_end, on_compile_start
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/convert_frame.py in <module>
#      51 from torch._dynamo.callback import CallbackTrigger
#      52 from torch._dynamo.distributed import get_compile_pg
# ---> 53 from torch._dynamo.symbolic_convert import TensorifyState
#      54 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      55 from torch._logging import structured
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/symbolic_convert.py in <module>
#      50 import torch
#      51 import torch._logging
# ---> 52 from torch._dynamo.exc import TensorifyScalarRestartAnalysis
#      53 from torch._guards import tracing, TracingContext
#      54 from torch._logging.structured import dump_file
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/exc.py in <module>
#      39
#      40 from . import config
# ---> 41 from .utils import counters
#      42
#      43
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/utils.py in <module>
#    2339 }
#    2340
# -> 2341 if has_triton_package():
#    2342     import triton
#    2343
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_triton.py in has_triton_package()
#       7 def has_triton_package() -> bool:
#       8     try:
# ----> 9         from triton.compiler.compiler import triton_key
#      10
#      11         return triton_key is not None
#
# /usr/local/lib/python3.12/dist-packages/triton/__init__.py in <module>
#       6
#       7 # submodules
# ----> 8 from .runtime import (
#       9     autotune,
#      10     Config,
#
# /usr/local/lib/python3.12/dist-packages/triton/runtime/__init__.py in <module>
# ----> 1 from .autotuner import (Autotuner, Config, Heuristics, autotune, heuristics)
#       2 from .cache import RedisRemoteCacheBackend, RemoteCacheBackend
#       3 from .driver import driver
#       4 from .jit import JITFunction, KernelInterface, MockTensor, TensorWrapper, reinterpret
#       5 from .errors import OutOfResources, InterpreterError
#
# /usr/local/lib/python3.12/dist-packages/triton/runtime/autotuner.py in <module>
#      10
#      11 from .. import knobs
# ---> 12 from .jit import KernelInterface
#      13 from .errors import OutOfResources, PTXASError
#      14 from .driver import driver
#
# /usr/local/lib/python3.12/dist-packages/triton/runtime/jit.py in <module>
#      15 from types import ModuleType
#      16 from .. import knobs
# ---> 17 from ..runtime.driver import driver
#      18 from .._utils import find_paths_if, get_iterable_path, type_canonicalisation_dict, canonicalize_dtype
#      19
#
# /usr/local/lib/python3.12/dist-packages/triton/runtime/driver.py in <module>
#       1 from __future__ import annotations
#       2
# ----> 3 from ..backends import backends, DriverBase
#       4
#       5 from typing import Any, Callable, Generic, TypeVar, Union
#
# /usr/local/lib/python3.12/dist-packages/triton/backends/__init__.py in <module>
#      45
#      46
# ---> 47 backends: dict[str, Backend] = _discover_backends()
#
# /usr/local/lib/python3.12/dist-packages/triton/backends/__init__.py in _discover_backends()
#      38     backends = dict()
#      39     for ep in entry_points().select(group="triton.backends"):
# ---> 40         compiler = importlib.import_module(f"{ep.value}.compiler")
#      41         driver = importlib.import_module(f"{ep.value}.driver")
#      42         backends[ep.name] = Backend(_find_concrete_subclasses(compiler, BaseBackend),  # type: ignore
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/triton/backends/amd/compiler.py in <module>
#       1 from triton.backends.compiler import BaseBackend, GPUTarget, Language
# ----> 2 from triton._C.libtriton import ir, passes, llvm, amd
#       3 from triton import knobs
#       4 from dataclasses import dataclass
#       5 from typing import Any, Dict, Tuple
#
# KeyboardInterrupt:

# %% [markdown]
# El error ocurre porque lo detuve ya que mi laptop no lo puede procesar tanto tiempo, pero deberia aparecer finalmente:
# ![image.png](data:image/png;base64,...)

# %%
classes_list = ['Left', 'Right']
eval_model = EvalModel(trained_eegnet_model)
test_accuracy = eval_model.test_model(test_dataset)
eval_model.plot_confusion_matrix(test_dataset, classes_list)
# Out:
# /------------------------------/
# Test Accuracy: 75.79%
# /------------------------------/

# %% [markdown]
# # 5. Evaluacion del modelo para la sesión 5 (Verificación)

# %% [markdown]
# ## 5.1 Preprocesamiento y procesamiento de datos para la sesión 5

# %%
# !unzip true_labels.zip -d five_session_labels
# Out:
# Archive:  true_labels.zip
# replace five_session_labels/B0401T.mat? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: five_session_labels/B0401T.mat
#   inflating: five_session_labels/B0403T.mat
#   inflating: five_session_labels/B0601T.mat
#   inflating: five_session_labels/B0202T.mat
#   inflating: five_session_labels/B0603T.mat
#   inflating: five_session_labels/B0104E.mat
#   inflating: five_session_labels/B0105E.mat
#   inflating: five_session_labels/B0802T.mat
#   inflating: five_session_labels/B0305E.mat
#   inflating: five_session_labels/B0501T.mat
#   inflating: five_session_labels/B0405E.mat
#   inflating: five_session_labels/B0702T.mat
#   inflating: five_session_labels/B0705E.mat
#   inflating: five_session_labels/B0605E.mat
#   inflating: five_session_labels/B0904E.mat
#   inflating: five_session_labels/B0203T.mat
#   inflating: five_session_labels/B0103T.mat
#   inflating: five_session_labels/B0404E.mat
#   inflating: five_session_labels/B0701T.mat
#   inflating: five_session_labels/B0505E.mat
#   inflating: five_session_labels/B0201T.mat
#   inflating: five_session_labels/B0301T.mat
#   inflating: five_session_labels/B0901T.mat
#   inflating: five_session_labels/B0205E.mat
#   inflating: five_session_labels/B0602T.mat
#   inflating: five_session_labels/B0801T.mat
#   inflating: five_session_labels/B0803T.mat
#   inflating: five_session_labels/B0902T.mat
#   inflating: five_session_labels/B0502T.mat
#   inflating: five_session_labels/B0703T.mat
#   inflating: five_session_labels/B0204E.mat
#   inflating: five_session_labels/B0402T.mat
#   inflating: five_session_labels/B0905E.mat
#   inflating: five_session_labels/B0704E.mat
#   inflating: five_session_labels/B0102T.mat
#   inflating: five_session_labels/B0604E.mat
#   inflating: five_session_labels/B0303T.mat
#   inflating: five_session_labels/B0804E.mat
#   inflating: five_session_labels/B0903T.mat
#   inflating: five_session_labels/B0503T.mat
#   inflating: five_session_labels/B0805E.mat
#   inflating: five_session_labels/B0304E.mat
#   inflating: five_session_labels/B0504E.mat
#   inflating: five_session_labels/B0101T.mat
#   inflating: five_session_labels/B0302T.mat

# %%
raw_data_folder = 'raw_data/'
cleaned_data_folder = 'cleaned_data/five_session/'
mat_folder = 'five_session_labels/'

# Filtrar archivos .mat para las etiquetas (ejemplo 4E.mat)
mat_files = os.listdir(mat_folder)
filtered_math_labels = [file for file in mat_files if file.endswith('05E.mat')]

# Filtrar archivos .gdf para la sesión (ejemplo 4E.gdf)
files = os.listdir(raw_data_folder)
filtered_files = [file for file in files if file.endswith('05E.gdf')]

raw_list = []

#Array de five_session_labels
five_session_labels = np.array([])

# Iteración sobre los .gdf
for file in filtered_files:
    file_path = os.path.join(raw_data_folder, file)

    # Leer datos
    raw = mne.io.read_raw_gdf(file_path,
                              eog=['EOG-left', 'EOG-central', 'EOG-right'],
                              preload=True)
    raw.drop_channels(['EOG:ch01', 'EOG:ch02', 'EOG:ch03'])
    raw.filter(l_freq=8, h_freq=30, method='iir')

    # Guardar .fif
    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')
    raw.save(new_file_path, overwrite=True)

    raw_list.append(raw)

    # Cargar labels del .mat correspondiente
    mat_file_name = file.replace('.gdf', '.mat')
    mat_file_path = os.path.join(mat_folder, mat_file_name)
    print(f"data:{file}, label:{mat_file_name}")

    if os.path.exists(mat_file_path):
        mat_data = scipy.io.loadmat(mat_file_path)
        class_labels = mat_data.get('classlabel', [])

        if class_labels.size > 0:
            class_labels_array = np.array(class_labels, dtype=int).flatten()
            five_session_labels = np.concatenate(
                (five_session_labels, class_labels_array)
            )
            print(f"Etiquetas cargadas: {class_labels_array.shape[0]}")
        else:
            print(f"Warning: 'classlabel' not found or empty in {mat_file_name}.")
    else:
        print(f"Warning: {mat_file_name} not found.")

# Concatenamos todos los raws
final_raw = mne.concatenate_raws(raw_list)
new_file_path = os.path.join(cleaned_data_folder, 'Five_Session_Subjects.fif')
final_raw.save(new_file_path, overwrite=True)
# Out:
# Extracting EDF parameters from /content/raw_data/B0905E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 458570  =      0.000 ...  1834.280 secs...
# /tmp/ipython-input-1331448909.py:23: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Overwriting existing file.
# Writing /content/cleaned_data/five_session/B0905E.fif
# Overwriting existing file.
# Closing /content/cleaned_data/five_session/B0905E.fif
# [done]
# data:B0905E.gdf, label:B0905E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0805E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 464306  =      0.000 ...  1857.224 secs...
# /tmp/ipython-input-1331448909.py:31: RuntimeWarning: This filename (/content/cleaned_data/five_session/B0905E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# /tmp/ipython-input-1331448909.py:23: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Overwriting existing file.
# Writing /content/cleaned_data/five_session/B0805E.fif
# Overwriting existing file.
# Closing /content/cleaned_data/five_session/B0805E.fif
# [done]
# data:B0805E.gdf, label:B0805E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0705E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 460894  =      0.000 ...  1843.576 secs...
# /tmp/ipython-input-1331448909.py:31: RuntimeWarning: This filename (/content/cleaned_data/five_session/B0805E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# /tmp/ipython-input-1331448909.py:23: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Overwriting existing file.
# Writing /content/cleaned_data/five_session/B0705E.fif
# Overwriting existing file.
# Closing /content/cleaned_data/five_session/B0705E.fif
# [done]
# data:B0705E.gdf, label:B0705E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0105E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 474362  =      0.000 ...  1897.448 secs...
# /tmp/ipython-input-1331448909.py:31: RuntimeWarning: This filename (/content/cleaned_data/five_session/B0705E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# /tmp/ipython-input-1331448909.py:23: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Overwriting existing file.
# Writing /content/cleaned_data/five_session/B0105E.fif
# Overwriting existing file.
# Closing /content/cleaned_data/five_session/B0105E.fif
# [done]
# data:B0105E.gdf, label:B0105E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0605E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 460902  =      0.000 ...  1843.608 secs...
# /tmp/ipython-input-1331448909.py:31: RuntimeWarning: This filename (/content/cleaned_data/five_session/B0105E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# /tmp/ipython-input-1331448909.py:23: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Overwriting existing file.
# Writing /content/cleaned_data/five_session/B0605E.fif
# Overwriting existing file.
# Closing /content/cleaned_data/five_session/B0605E.fif
# [done]
# data:B0605E.gdf, label:B0605E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0305E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 463618  =      0.000 ...  1854.472 secs...
# /tmp/ipython-input-1331448909.py:31: RuntimeWarning: This filename (/content/cleaned_data/five_session/B0605E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# /tmp/ipython-input-1331448909.py:23: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Overwriting existing file.
# Writing /content/cleaned_data/five_session/B0305E.fif
# Overwriting existing file.
# Closing /content/cleaned_data/five_session/B0305E.fif
# [done]
# data:B0305E.gdf, label:B0305E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0505E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 464958  =      0.000 ...  1859.832 secs...
# /tmp/ipython-input-1331448909.py:31: RuntimeWarning: This filename (/content/cleaned_data/five_session/B0305E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# /tmp/ipython-input-1331448909.py:23: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Overwriting existing file.
# Writing /content/cleaned_data/five_session/B0505E.fif
# Overwriting existing file.
# Closing /content/cleaned_data/five_session/B0505E.fif
# [done]
# data:B0505E.gdf, label:B0505E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0205E.gdf...
# /tmp/ipython-input-1331448909.py:31: RuntimeWarning: This filename (/content/cleaned_data/five_session/B0505E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 473686  =      0.000 ...  1894.744 secs...
# /tmp/ipython-input-1331448909.py:23: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Overwriting existing file.
# Writing /content/cleaned_data/five_session/B0205E.fif
# Overwriting existing file.
# /tmp/ipython-input-1331448909.py:31: RuntimeWarning: This filename (/content/cleaned_data/five_session/B0205E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/five_session/B0205E.fif
# [done]
# data:B0205E.gdf, label:B0205E.mat
# Etiquetas cargadas: 160
# Extracting EDF parameters from /content/raw_data/B0405E.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 466050  =      0.000 ...  1864.200 secs...
# /tmp/ipython-input-1331448909.py:23: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path,
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
#
# Overwriting existing file.
# Writing /content/cleaned_data/five_session/B0405E.fif
# Overwriting existing file.
# Closing /content/cleaned_data/five_session/B0405E.fif
# [done]
# data:B0405E.gdf, label:B0405E.mat
# Etiquetas cargadas: 160
# /tmp/ipython-input-1331448909.py:31: RuntimeWarning: This filename (/content/cleaned_data/five_session/B0405E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Overwriting existing file.
# Writing /content/cleaned_data/five_session/Five_Session_Subjects.fif
# Overwriting existing file.
# /tmp/ipython-input-1331448909.py:58: RuntimeWarning: This filename (/content/cleaned_data/five_session/Five_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/five_session/Five_Session_Subjects.fif
# [done]
# [PosixPath('/content/cleaned_data/five_session/Five_Session_Subjects.fif')]

# %%
# Cargar el archivo .mat que tiene las etiquetas
mat_data = loadmat("five_session_labels/B0105E.mat")   # ajusta con tu archivo real
labels_mat = mat_data['classlabel'].squeeze()  # (160,)
print(labels_mat.shape)  # debería dar (160,)

print("Total etiquetas:", labels_mat.shape[0])
print("Ejemplo de clases únicas:", np.unique(labels_mat))
# Out:
# (160,)
# Total etiquetas: 160
# Ejemplo de clases únicas: [1 2]

# %%
events, event_dict = mne.events_from_annotations(final_raw)
events[1]

# Mostrar los eventos únicos encontrados
print("Eventos encontrados:", event_dict)

print(events.shape)
print(events[:5])  # Primeros 5 eventos

epochs = mne.Epochs(final_raw, events, event_id=11, tmin=0.5, tmax=4, reject=None, baseline=None, preload=None)

five_session_data = epochs.get_data(copy=True)

print("Five Session Dataset shape:", five_session_data.shape)
print("Total etiquetas cargadas:", five_session_labels.shape)
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1077'), np.str_('1078'), np.str_('1079'), np.str_('1081'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('781'), np.str_('783')]
# Eventos encontrados: {np.str_('1023'): 1, np.str_('1077'): 2, np.str_('1078'): 3, np.str_('1079'): 4, np.str_('1081'): 5, np.str_('276'): 6, np.str_('277'): 7, np.str_('32766'): 8, np.str_('768'): 9, np.str_('781'): 10, np.str_('783'): 11}
# (4743, 3)
# [[    0     0     8]
#  [  499     0     6]
#  [16749     0     7]
#  [32999     0     5]
#  [37999     0     4]]
# Not setting metadata
# 1440 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1440 events and 876 original time points ...
# 0 bad epochs dropped
# Five Session Dataset shape: (1440, 3, 876)
# Total etiquetas cargadas: (1440,)

# %% [markdown]
# ## 5.2 Improtación del los pesos del modelo y validación de clasificación

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

# -------------------------------
# 1. Definir el modelo y cargar pesos
# -------------------------------
model = EEGNetModel(
    chans=3,
    classes=2,
    time_points=876,
    temp_kernel=32,
    f1=16,
    f2=32,
    d=2,
    pk1=8,
    pk2=16,
    dropout_rate=0.5,
    max_norm1=1,
    max_norm2=0.25
)

# Cargar pesos entrenados
model.load_state_dict(torch.load("eegnet2b_model.pth", map_location=device))
model = model.to(device)
model.eval()

# -------------------------------
# 2. Preparar datos de five_session
# -------------------------------
# Normalizar etiquetas (de {1,2} → {0,1})
y_five = five_session_labels - np.min(five_session_labels)

# Normalizar características (z-score global)
X_five = (five_session_data - np.mean(five_session_data)) / np.std(five_session_data)

# Convertir a tensores [batch, 1, chans, time_points]
X_five = torch.Tensor(X_five).unsqueeze(1).to(device)   # [1440, 1, 3, 1001]
y_five = torch.LongTensor(y_five).to(device)

# Crear dataset y dataloader
test_dataset = TensorDataset(X_five, y_five)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

print("Size of X_five:", X_five.size())  # Debe ser [1440, 1, 3, 1001]
print("Size of y_five:", y_five.size())

# -------------------------------
# 3. Evaluación manual
# -------------------------------
correct = 0
total = 0

with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)

        # Evento real tomado de epochs.events
        true_event = epochs.events[i, 2]

        print(f"Epoch {i}: etiqueta real = {labels.item()}, evento = {true_event}, predicción = {predicted.item()}")

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f"\nPrecisión total: {accuracy:.2f}%")
print("Dimensiones:", len(five_session_labels), len(five_session_data), len(epochs.events))
# Out:
# Size of X_five: torch.Size([1440, 1, 3, 876])
# Size of y_five: torch.Size([1440])
# Epoch 0: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 2: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 3: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 4: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 5: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 6: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 7: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 8: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 9: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 10: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 11: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 12: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 13: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 14: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 15: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 16: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 17: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 18: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 19: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 20: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 21: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 22: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 23: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 24: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 25: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 26: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 27: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 28: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 29: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 30: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 31: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 32: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 33: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 34: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 35: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 36: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 37: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 38: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 39: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 40: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 41: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 42: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 43: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 44: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 45: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 46: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 47: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 48: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 49: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 50: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 51: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 52: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 53: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 54: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 55: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 56: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 57: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 58: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 59: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 60: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 61: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 62: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 63: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 64: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 65: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 66: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 67: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 68: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 69: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 70: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 71: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 72: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 73: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 74: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 75: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 76: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 77: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 78: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 79: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 80: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 81: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 82: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 83: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 84: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 85: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 86: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 87: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 88: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 89: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 90: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 91: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 92: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 93: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 94: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 95: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 96: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 97: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 98: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 99: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 100: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 101: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 102: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 103: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 104: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 105: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 106: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 107: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 108: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 109: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 110: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 111: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 112: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 113: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 114: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 115: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 116: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 117: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 118: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 119: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 120: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 121: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 122: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 123: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 124: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 125: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 126: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 127: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 128: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 129: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 130: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 131: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 132: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 133: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 134: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 135: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 136: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 137: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 138: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 139: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 140: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 141: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 142: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 143: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 144: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 145: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 146: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 147: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 148: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 149: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 150: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 151: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 152: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 153: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 154: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 155: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 156: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 157: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 158: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 159: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 160: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 161: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 162: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 163: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 164: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 165: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 166: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 167: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 168: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 169: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 170: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 171: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 172: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 173: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 174: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 175: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 176: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 177: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 178: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 179: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 180: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 181: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 182: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 183: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 184: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 185: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 186: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 187: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 188: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 189: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 190: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 191: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 192: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 193: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 194: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 195: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 196: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 197: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 198: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 199: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 200: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 201: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 202: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 203: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 204: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 205: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 206: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 207: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 208: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 209: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 210: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 211: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 212: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 213: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 214: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 215: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 216: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 217: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 218: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 219: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 220: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 221: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 222: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 223: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 224: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 225: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 226: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 227: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 228: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 229: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 230: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 231: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 232: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 233: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 234: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 235: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 236: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 237: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 238: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 239: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 240: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 241: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 242: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 243: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 244: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 245: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 246: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 247: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 248: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 249: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 250: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 251: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 252: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 253: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 254: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 255: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 256: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 257: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 258: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 259: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 260: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 261: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 262: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 263: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 264: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 265: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 266: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 267: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 268: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 269: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 270: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 271: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 272: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 273: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 274: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 275: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 276: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 277: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 278: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 279: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 280: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 281: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 282: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 283: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 284: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 285: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 286: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 287: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 288: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 289: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 290: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 291: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 292: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 293: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 294: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 295: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 296: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 297: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 298: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 299: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 300: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 301: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 302: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 303: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 304: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 305: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 306: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 307: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 308: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 309: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 310: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 311: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 312: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 313: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 314: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 315: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 316: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 317: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 318: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 319: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 320: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 321: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 322: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 323: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 324: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 325: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 326: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 327: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 328: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 329: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 330: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 331: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 332: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 333: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 334: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 335: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 336: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 337: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 338: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 339: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 340: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 341: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 342: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 343: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 344: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 345: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 346: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 347: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 348: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 349: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 350: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 351: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 352: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 353: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 354: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 355: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 356: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 357: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 358: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 359: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 360: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 361: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 362: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 363: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 364: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 365: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 366: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 367: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 368: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 369: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 370: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 371: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 372: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 373: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 374: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 375: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 376: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 377: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 378: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 379: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 380: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 381: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 382: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 383: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 384: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 385: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 386: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 387: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 388: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 389: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 390: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 391: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 392: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 393: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 394: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 395: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 396: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 397: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 398: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 399: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 400: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 401: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 402: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 403: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 404: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 405: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 406: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 407: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 408: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 409: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 410: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 411: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 412: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 413: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 414: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 415: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 416: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 417: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 418: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 419: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 420: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 421: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 422: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 423: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 424: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 425: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 426: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 427: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 428: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 429: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 430: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 431: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 432: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 433: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 434: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 435: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 436: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 437: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 438: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 439: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 440: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 441: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 442: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 443: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 444: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 445: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 446: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 447: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 448: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 449: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 450: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 451: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 452: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 453: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 454: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 455: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 456: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 457: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 458: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 459: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 460: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 461: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 462: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 463: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 464: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 465: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 466: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 467: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 468: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 469: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 470: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 471: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 472: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 473: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 474: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 475: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 476: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 477: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 478: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 479: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 480: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 481: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 482: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 483: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 484: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 485: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 486: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 487: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 488: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 489: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 490: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 491: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 492: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 493: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 494: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 495: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 496: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 497: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 498: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 499: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 500: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 501: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 502: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 503: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 504: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 505: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 506: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 507: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 508: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 509: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 510: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 511: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 512: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 513: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 514: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 515: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 516: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 517: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 518: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 519: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 520: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 521: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 522: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 523: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 524: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 525: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 526: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 527: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 528: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 529: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 530: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 531: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 532: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 533: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 534: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 535: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 536: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 537: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 538: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 539: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 540: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 541: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 542: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 543: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 544: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 545: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 546: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 547: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 548: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 549: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 550: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 551: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 552: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 553: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 554: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 555: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 556: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 557: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 558: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 559: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 560: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 561: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 562: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 563: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 564: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 565: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 566: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 567: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 568: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 569: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 570: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 571: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 572: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 573: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 574: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 575: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 576: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 577: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 578: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 579: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 580: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 581: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 582: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 583: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 584: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 585: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 586: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 587: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 588: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 589: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 590: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 591: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 592: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 593: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 594: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 595: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 596: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 597: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 598: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 599: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 600: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 601: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 602: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 603: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 604: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 605: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 606: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 607: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 608: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 609: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 610: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 611: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 612: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 613: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 614: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 615: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 616: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 617: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 618: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 619: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 620: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 621: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 622: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 623: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 624: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 625: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 626: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 627: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 628: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 629: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 630: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 631: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 632: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 633: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 634: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 635: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 636: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 637: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 638: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 639: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 640: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 641: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 642: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 643: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 644: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 645: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 646: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 647: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 648: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 649: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 650: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 651: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 652: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 653: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 654: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 655: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 656: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 657: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 658: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 659: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 660: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 661: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 662: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 663: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 664: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 665: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 666: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 667: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 668: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 669: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 670: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 671: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 672: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 673: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 674: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 675: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 676: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 677: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 678: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 679: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 680: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 681: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 682: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 683: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 684: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 685: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 686: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 687: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 688: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 689: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 690: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 691: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 692: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 693: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 694: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 695: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 696: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 697: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 698: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 699: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 700: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 701: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 702: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 703: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 704: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 705: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 706: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 707: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 708: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 709: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 710: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 711: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 712: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 713: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 714: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 715: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 716: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 717: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 718: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 719: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 720: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 721: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 722: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 723: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 724: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 725: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 726: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 727: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 728: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 729: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 730: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 731: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 732: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 733: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 734: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 735: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 736: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 737: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 738: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 739: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 740: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 741: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 742: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 743: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 744: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 745: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 746: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 747: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 748: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 749: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 750: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 751: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 752: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 753: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 754: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 755: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 756: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 757: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 758: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 759: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 760: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 761: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 762: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 763: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 764: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 765: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 766: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 767: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 768: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 769: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 770: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 771: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 772: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 773: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 774: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 775: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 776: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 777: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 778: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 779: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 780: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 781: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 782: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 783: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 784: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 785: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 786: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 787: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 788: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 789: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 790: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 791: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 792: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 793: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 794: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 795: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 796: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 797: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 798: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 799: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 800: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 801: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 802: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 803: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 804: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 805: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 806: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 807: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 808: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 809: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 810: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 811: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 812: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 813: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 814: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 815: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 816: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 817: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 818: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 819: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 820: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 821: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 822: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 823: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 824: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 825: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 826: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 827: etiqueta real = 0, evento = 11, predicción = 1
# ...
# Epoch 1170: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1171: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1172: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1173: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1174: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1175: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1176: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1177: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1178: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1179: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1180: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1181: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1182: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1183: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1184: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1185: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1186: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1187: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1188: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1189: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1190: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1191: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1192: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1193: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1194: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1195: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1196: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1197: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1198: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1199: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1200: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1201: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1202: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1203: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1204: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1205: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1206: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1207: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1208: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1209: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1210: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1211: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1212: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1213: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1214: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1215: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1216: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1217: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1218: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1219: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1220: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1221: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1222: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1223: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1224: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1225: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1226: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1227: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1228: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1229: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1230: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1231: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1232: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1233: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1234: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1235: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1236: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1237: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1238: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1239: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1240: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1241: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1242: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1243: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1244: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1245: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1246: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1247: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1248: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1249: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1250: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1251: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1252: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1253: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1254: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1255: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1256: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1257: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1258: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1259: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1260: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1261: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1262: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1263: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1264: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1265: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1266: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1267: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1268: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1269: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1270: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1271: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1272: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1273: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1274: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1275: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1276: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1277: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1278: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1279: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1280: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1281: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1282: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1283: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1284: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1285: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1286: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1287: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1288: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1289: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1290: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1291: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1292: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1293: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1294: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1295: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1296: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1297: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1298: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1299: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1300: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1301: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1302: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1303: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1304: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1305: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1306: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1307: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1308: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1309: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1310: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1311: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1312: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1313: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1314: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1315: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1316: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1317: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1318: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1319: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1320: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1321: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1322: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1323: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1324: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1325: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1326: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1327: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1328: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1329: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1330: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1331: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1332: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1333: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1334: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1335: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1336: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1337: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1338: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1339: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1340: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1341: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1342: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1343: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1344: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1345: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1346: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1347: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1348: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1349: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1350: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1351: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1352: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1353: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1354: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1355: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1356: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1357: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1358: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1359: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1360: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1361: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1362: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1363: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1364: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1365: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1366: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1367: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1368: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1369: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1370: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1371: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1372: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1373: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1374: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1375: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1376: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1377: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1378: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1379: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1380: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1381: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1382: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1383: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1384: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1385: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1386: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1387: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1388: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1389: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1390: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1391: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1392: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1393: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1394: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1395: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1396: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1397: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1398: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1399: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1400: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1401: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1402: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1403: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1404: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1405: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1406: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1407: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1408: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1409: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1410: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1411: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1412: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1413: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1414: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1415: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1416: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1417: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1418: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1419: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1420: etiqueta real = 0, evento = 11, predicción = 1
# Epoch 1421: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1422: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1423: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1424: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1425: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1426: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1427: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1428: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1429: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1430: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1431: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1432: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1433: etiqueta real = 1, evento = 11, predicción = 0
# Epoch 1434: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1435: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1436: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1437: etiqueta real = 1, evento = 11, predicción = 1
# Epoch 1438: etiqueta real = 0, evento = 11, predicción = 0
# Epoch 1439: etiqueta real = 0, evento = 11, predicción = 0
#
# Precisión total: 76.25%
# Dimensiones: 1440 1440 1440
